# %% [markdown]
# <a href="https://colab.research.google.com/github/KarinaZubko/Portfolio/blob/main/Marathon/Marathon_Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)

# %%
import pandas as pd
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

# %%
df = pd.read_csv('ff_race_50.csv')

# %%
df. columns=df.iloc[0]
df = df[1:]
df.head()
# Out:
# 0 Place    First     Last              City State Age Division     Time
# 1     1   Daniel   Wilson             Tulsa    OK  35        M  8:23:01
# 2     2     Eric    Davis         Greenwood    IN  38        M  8:57:54
# 3     3  Stewart  Edwards  New Smyrna Beach    FL  43        M  9:24:35
# 4     4      Ron  Hammett         Montverde    FL  53        M  9:24:36
# 5     5     Seth     Cain            Geneva    FL  44        M  9:42:17

# %%
df2 = df.dropna(axis=1)

# %%
df2.head()
# Out:
# 0 Place    First     Last              City State Age Division     Time
# 1     1   Daniel   Wilson             Tulsa    OK  35        M  8:23:01
# 2     2     Eric    Davis         Greenwood    IN  38        M  8:57:54
# 3     3  Stewart  Edwards  New Smyrna Beach    FL  43        M  9:24:35
# 4     4      Ron  Hammett         Montverde    FL  53        M  9:24:36
# 5     5     Seth     Cain            Geneva    FL  44        M  9:42:17

# %%
# Creating the column for combining first and last names
df2['FullName'] = df2['First'] + [' '] +df2['Last']

# %%
df2.head()
# Out:
# 0 Place    First     Last              City State Age Division     Time  \
# 1     1   Daniel   Wilson             Tulsa    OK  35        M  8:23:01
# 2     2     Eric    Davis         Greenwood    IN  38        M  8:57:54
# 3     3  Stewart  Edwards  New Smyrna Beach    FL  43        M  9:24:35
# 4     4      Ron  Hammett         Montverde    FL  53        M  9:24:36
# 5     5     Seth     Cain            Geneva    FL  44        M  9:42:17
#
# 0         FullName
# 1    Daniel Wilson
# 2       Eric Davis
# 3  Stewart Edwards
# 4      Ron Hammett
# 5        Seth Cain

# %%
# time conversion
df2['Time'] = pd.to_timedelta(df2['Time'])

# %%
df2['Total_Minutes'] = df2['Time'].dt.total_seconds() / 60

# %%
df2['Total_Minutes'] = df2['Total_Minutes'].round().astype(int)

# %%
df2.head()
# Out:
# 0 Place    First     Last              City State Age Division  \
# 1     1   Daniel   Wilson             Tulsa    OK  35        M
# 2     2     Eric    Davis         Greenwood    IN  38        M
# 3     3  Stewart  Edwards  New Smyrna Beach    FL  43        M
# 4     4      Ron  Hammett         Montverde    FL  53        M
# 5     5     Seth     Cain            Geneva    FL  44        M
#
# 0            Time         FullName  Total_Minutes
# 1 0 days 08:23:01    Daniel Wilson            503
# 2 0 days 08:57:54       Eric Davis            538
# 3 0 days 09:24:35  Stewart Edwards            565
# 4 0 days 09:24:36      Ron Hammett            565
# 5 0 days 09:42:17        Seth Cain            582

# %%
df2.rename(columns={'Division':'Gender'}, inplace=True)

# %%
def get_lat_long(city, state):
    address = f"{city},{state}"
    try:
        geolocator = Nominatim(user_agent="running", timeout=10)
        location = geolocator.geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except GeocoderTimedOut:
        return None, None

# %%
df2.head()
# Out:
# 0 Place    First     Last              City State Age Gender            Time  \
# 1     1   Daniel   Wilson             Tulsa    OK  35      M 0 days 08:23:01
# 2     2     Eric    Davis         Greenwood    IN  38      M 0 days 08:57:54
# 3     3  Stewart  Edwards  New Smyrna Beach    FL  43      M 0 days 09:24:35
# 4     4      Ron  Hammett         Montverde    FL  53      M 0 days 09:24:36
# 5     5     Seth     Cain            Geneva    FL  44      M 0 days 09:42:17
#
# 0         FullName  Total_Minutes
# 1    Daniel Wilson            503
# 2       Eric Davis            538
# 3  Stewart Edwards            565
# 4      Ron Hammett            565
# 5        Seth Cain            582

# %%
df2['latitude'],df2['longitude'] = zip(*df2.apply(lambda x: get_lat_long(x['City'],x['State']), axis = 1))

# %%
df2.head()
# Out:
# 0 Place    First     Last              City State Age Gender            Time  \
# 1     1   Daniel   Wilson             Tulsa    OK  35      M 0 days 08:23:01
# 2     2     Eric    Davis         Greenwood    IN  38      M 0 days 08:57:54
# 3     3  Stewart  Edwards  New Smyrna Beach    FL  43      M 0 days 09:24:35
# 4     4      Ron  Hammett         Montverde    FL  53      M 0 days 09:24:36
# 5     5     Seth     Cain            Geneva    FL  44      M 0 days 09:42:17
#
# 0         FullName  Total_Minutes   latitude  longitude
# 1    Daniel Wilson            503  36.156312 -95.992752
# 2       Eric Davis            538  39.613699 -86.109543
# 3  Stewart Edwards            565  29.025813 -80.927127
# 4      Ron Hammett            565  28.600277 -81.673964
# 5        Seth Cain            582  28.737294 -81.113420

# %%
df2['latlong'] = df2['latitude'].astype(str) + ', ' + df2['longitude'].astype(str)

# %%
df2.head()
# Out:
# 0 Place    First     Last              City State Age Gender            Time  \
# 1     1   Daniel   Wilson             Tulsa    OK  35      M 0 days 08:23:01
# 2     2     Eric    Davis         Greenwood    IN  38      M 0 days 08:57:54
# 3     3  Stewart  Edwards  New Smyrna Beach    FL  43      M 0 days 09:24:35
# 4     4      Ron  Hammett         Montverde    FL  53      M 0 days 09:24:36
# 5     5     Seth     Cain            Geneva    FL  44      M 0 days 09:42:17
#
# 0         FullName  Total_Minutes   latitude  longitude  \
# 1    Daniel Wilson            503  36.156312 -95.992752
# 2       Eric Davis            538  39.613699 -86.109543
# 3  Stewart Edwards            565  29.025813 -80.927127
# 4      Ron Hammett            565  28.600277 -81.673964
# 5        Seth Cain            582  28.737294 -81.113420
#
# 0                        latlong
# 1        36.1563122, -95.9927516
# 2        39.6136987, -86.1095429
# 3        29.0258132, -80.9271271
# 4         28.6002769, -81.673964
# 5  28.737294, -81.11342048773265

# %%
 df2.to_csv('ultracleanedupdata_outupt.csv', index = False)
